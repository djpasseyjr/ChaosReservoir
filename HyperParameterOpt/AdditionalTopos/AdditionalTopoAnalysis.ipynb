# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
f4 = "/Users/djpassey/Downloads/compiled_output_dj4_loop.pkl"
f5 = "/Users/djpassey/Downloads/compiled_output_dj5_chain.pkl"
f6 = "/Users/djpassey/Downloads/compiled_output_dj6_no_edges.pkl"
f7 = "/Users/djpassey/Downloads/compiled_output_dj7_ident.pkl"

# %% [markdown]
# ## No Edges

# %%
no_edges = pd.DataFrame(pd.read_pickle(f6))
no_edges.describe()
# Out:
#           mean_pred      mean_err      adj_size  topo_p         gamma  \
# count  64825.000000  64825.000000  64825.000000  2325.0  64825.000000
# mean    1039.746394      3.347011   1445.815658     0.0      2.744003
# std     1359.905510      4.009506    848.915718     0.0      3.259482
# min        0.000000      0.000000      0.000000     0.0      0.000000
# 25%        0.000000      0.165096    500.000000     0.0      0.500000
# 50%      446.000000      0.926840   1500.000000     0.0      1.000000
# 75%     1561.000000      7.471954   2500.000000     0.0      5.000000
# max     4995.000000     14.921374   2500.000000     0.0     10.000000
#
#               sigma     spect_rad   ridge_alpha  remove_p       exp_num
# count  64825.000000  64825.000000  64825.000000   64825.0  64825.000000
# mean       0.172076      2.393367      0.244240       0.0   1297.000000
# std        0.335826      3.336612      0.426824       0.0    748.540342
# ...

# %%
no_edges_hyp = no_edges.groupby(no_edges['exp_num']).aggregate(np.mean)
no_edges_hyp.describe()
# Out:
#          mean_pred     mean_err     adj_size  topo_p        gamma  \
# count  2593.000000  2593.000000  2593.000000    93.0  2593.000000
# mean   1039.746394     3.347011  1445.815658     0.0     2.744003
# std    1215.012706     4.008412   849.072910     0.0     3.260086
# min       0.000000     0.000000     0.000000     0.0     0.000000
# 25%      19.480000     0.165909   500.000000     0.0     0.500000
# 50%     612.920000     0.934672  1500.000000     0.0     1.000000
# 75%    1648.000000     7.484485  2500.000000     0.0     5.000000
# max    4345.560000    14.567065  2500.000000     0.0    10.000000
#
#              sigma    spect_rad  ridge_alpha  remove_p
# count  2593.000000  2593.000000  2593.000000    2593.0
# mean      0.172076     2.393367     0.244240       0.0
# std       0.335888     3.337230     0.426903       0.0
# min       0.000000     0.000000     0.000000       0.0
# 25%       0.005000     0.900000     0.000001       0.0
# ...

# %% [markdown]
# ## Chain

# %%
chain = pd.DataFrame(pd.read_pickle(f5))
chain.describe()
# Out:
#            mean_pred       mean_err       adj_size    topo_p          gamma  \
# count  648025.000000  648025.000000  648025.000000  583275.0  648025.000000
# mean      110.798387       0.187717     149.839898       0.0       0.309216
# std       526.044024       1.162119     518.532463       0.0       1.437911
# min         0.000000       0.000000       0.000000       0.0       0.000000
# 25%         0.000000       0.000000       0.000000       0.0       0.000000
# 50%         0.000000       0.000000       0.000000       0.0       0.000000
# 75%         0.000000       0.000000       0.000000       0.0       0.000000
# max      4995.000000      14.795625    2500.000000       0.0      10.000000
#
#                sigma      spect_rad    ridge_alpha  remove_p        exp_num
# count  648025.000000  648025.000000  648025.000000  648025.0  648025.000000
# mean        0.020022       0.250885       0.025252       0.0   12961.000000
# ...

# %%
chain_hyp = chain.groupby(chain['exp_num']).aggregate(np.mean)
chain_hyp.describe()
# Out:
#           mean_pred      mean_err      adj_size   topo_p         gamma  \
# count  25921.000000  25921.000000  25921.000000  23331.0  25921.000000
# mean     110.798387      0.187717    149.839898      0.0      0.309216
# std      478.519103      1.161753    518.542065      0.0      1.437938
# min        0.000000      0.000000      0.000000      0.0      0.000000
# 25%        0.000000      0.000000      0.000000      0.0      0.000000
# 50%        0.000000      0.000000      0.000000      0.0      0.000000
# 75%        0.000000      0.000000      0.000000      0.0      0.000000
# max     4192.200000     14.144379   2500.000000      0.0     10.000000
#
#               sigma     spect_rad   ridge_alpha  remove_p
# count  25921.000000  25921.000000  25921.000000   25921.0
# mean       0.020022      0.250885      0.025252       0.0
# std        0.128682      1.308882      0.156092       0.0
# min        0.000000      0.000000      0.000000       0.0
# ...

# %% [markdown]
# ## Loop

# %%
loop = pd.DataFrame(pd.read_pickle(f4))
loop.describe()
# Out:
#            mean_pred       mean_err       adj_size    topo_p          gamma  \
# count  648025.000000  648025.000000  648025.000000  583275.0  648025.000000
# mean       96.452416       0.397558     149.839898       0.0       0.309216
# std       495.496609       2.079950     518.532463       0.0       1.437911
# min         0.000000       0.000000       0.000000       0.0       0.000000
# 25%         0.000000       0.000000       0.000000       0.0       0.000000
# 50%         0.000000       0.000000       0.000000       0.0       0.000000
# 75%         0.000000       0.000000       0.000000       0.0       0.000000
# max      4995.000000      15.026713    2500.000000       0.0      10.000000
#
#                sigma      spect_rad    ridge_alpha  remove_p        exp_num
# count  648025.000000  648025.000000  648025.000000  648025.0  648025.000000
# mean        0.020022       0.250885       0.025252       0.0   12961.000000
# ...

# %%
loop_hyp = loop.groupby(loop['exp_num']).aggregate(np.mean)
loop_hyp.describe()
# Out:
#           mean_pred      mean_err      adj_size   topo_p         gamma  \
# count  25921.000000  25921.000000  25921.000000  23331.0  25921.000000
# mean      96.452416      0.397558    149.839898      0.0      0.309216
# std      450.232266      2.079525    518.542065      0.0      1.437938
# min        0.000000      0.000000      0.000000      0.0      0.000000
# 25%        0.000000      0.000000      0.000000      0.0      0.000000
# 50%        0.000000      0.000000      0.000000      0.0      0.000000
# 75%        0.000000      0.000000      0.000000      0.0      0.000000
# max     4247.720000     14.722423   2500.000000      0.0     10.000000
#
#               sigma     spect_rad   ridge_alpha  remove_p
# count  25921.000000  25921.000000  25921.000000   25921.0
# mean       0.020022      0.250885      0.025252       0.0
# std        0.128682      1.308882      0.156092       0.0
# min        0.000000      0.000000      0.000000       0.0
# ...

# %% [markdown]
# ## Identity

# %%
ident = pd.DataFrame(pd.read_pickle(f7))
ident.describe()
# Out:
#            mean_pred       mean_err       adj_size    topo_p          gamma  \
# count  648025.000000  648025.000000  648025.000000  587275.0  648025.000000
# mean       43.595232       0.484962     140.580996       0.0       0.262150
# std       288.862792       2.183026     503.574392       0.0       1.277165
# min         0.000000       0.000000       0.000000       0.0       0.000000
# 25%         0.000000       0.000000       0.000000       0.0       0.000000
# 50%         0.000000       0.000000       0.000000       0.0       0.000000
# 75%         0.000000       0.000000       0.000000       0.0       0.000000
# max      4995.000000      15.092760    2500.000000       0.0      10.000000
#
#                sigma      spect_rad    ridge_alpha  remove_p        exp_num
# count  648025.000000  648025.000000  648025.000000  648025.0  648025.000000
# mean        0.018211       0.233031       0.023731       0.0   12961.000000
# ...

# %%
ident_hyp = ident.groupby(ident['exp_num']).aggregate(np.mean)
ident_hyp.describe()
# Out:
#           mean_pred      mean_err      adj_size   topo_p         gamma  \
# count  25921.000000  25921.000000  25921.000000  23491.0  25921.000000
# mean      43.595232      0.484962    140.580996      0.0      0.262150
# std      254.608225      2.182242    503.583718      0.0      1.277188
# min        0.000000      0.000000      0.000000      0.0      0.000000
# 25%        0.000000      0.000000      0.000000      0.0      0.000000
# 50%        0.000000      0.000000      0.000000      0.0      0.000000
# 75%        0.000000      0.000000      0.000000      0.0      0.000000
# max     4032.120000     14.708715   2500.000000      0.0     10.000000
#
#               sigma     spect_rad   ridge_alpha  remove_p
# count  25921.000000  25921.000000  25921.000000   25921.0
# mean       0.018211      0.233031      0.023731       0.0
# std        0.122725      1.260999      0.151442       0.0
# min        0.000000      0.000000      0.000000       0.0
# ...

# %%
best = ident_hyp[ident_hyp["mean_pred"] > 1000]
best.describe()
# Out:
#          mean_pred    mean_err     adj_size  topo_p       gamma       sigma  \
# count   420.000000  420.000000   420.000000     0.0  420.000000  420.000000
# mean   1775.590762    0.123976  1569.047619     NaN    4.113571    0.432393
# std     675.959544    0.156823   813.075747     NaN    3.495463    0.429571
# min    1000.520000    0.008836   500.000000     NaN    0.100000    0.005000
# 25%    1210.350000    0.026121   500.000000     NaN    1.000000    0.140000
# 50%    1572.820000    0.058931  1500.000000     NaN    5.000000    0.140000
# 75%    2156.900000    0.144681  2500.000000     NaN    5.000000    1.000000
# max    4032.120000    0.851840  2500.000000     NaN   10.000000    1.000000
#
#         spect_rad  ridge_alpha  remove_p
# count  420.000000   420.000000     420.0
# mean     0.909524     0.056294       0.0
# std      0.624943     0.227445       0.0
# min      0.100000     0.000001       0.0
# 25%      0.100000     0.000001       0.0
# ...

# %%
best
# Out:
#          mean_pred  mean_err  adj_size  topo_p  gamma  sigma  spect_rad  \
# exp_num
# 20251      4004.00  0.023311     500.0     NaN    5.0   0.14        0.1
# 20271      4032.12  0.019826    2500.0     NaN    5.0   0.14        0.1
#
#          ridge_alpha  remove_p
# exp_num
# 20251       0.000001       0.0
# 20271       0.000001       0.0

# %%
ran = ident_hyp[ident_hyp["sigma"] > 0]

# %%
ran.hist(bins=50)
plt.show()
