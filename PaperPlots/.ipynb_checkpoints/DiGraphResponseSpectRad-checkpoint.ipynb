# %%
import rescomp as rc
import numpy as np
from matplotlib import pyplot as plt

# %%
RES_PARAMS = {
              "uniform_weights": True,
              "ridge_alpha": 1e-6,
              "signal_dim": 3,
              "res_sz": 500,
              "activ_f": np.tanh,
              "gamma": 5,
              "sigma": .14,
             }

def digraph_err(mean_degree, rho):
    rcomp = rc.ResComp(**RES_PARAMS, spect_rad=rho, mean_degree=mean_degree)
    n = RES_PARAMS["res_sz"]
    t, U = rc.orbit("lorenz", trim=True)
    r0 = np.random.rand(n)*2 - 1
    R = rcomp.internal_state_response(t, U, r0)
    Wout = U.T @ R @ np.linalg.inv(R.T @ R)
    Uhat = (Wout@R.T).T
    inferr = np.max(np.abs(Uhat - U))
    l2err = np.mean(np.sum((Uhat - U)**2, axis=1)**.5)
    return inferr, l2err

# %%
rho = 0.5
mean_degree = 0.001

rcomp = rc.ResComp(**RES_PARAMS, spect_rad=rho, mean_degree=mean_degree)
n = RES_PARAMS["res_sz"]
t, U = rc.orbit("lorenz", trim=True)
r0 = np.random.rand(n)*2 - 1
R = rcomp.internal_state_response(t, U, r0)
Wout = U.T @ R @ np.linalg.inv(R.T @ R)
Uhat = (Wout@R.T).T

plt.plot(Uhat)
plt.show()

# %%
R = rcomp.internal_state_response(t, U, r0)
plt.plot(t - 40, R)
plt.show()

Wout = U.T @ R @ np.linalg.inv(R.T @ R)
Uhat = (Wout@R.T).T
#plt.plot(Uhat)
err = np.max(np.abs(Uhat - U))
print(f"Error {err} (Probably should do mean)")
# Out:
# Error 1.0088298496463697 (Probably should do mean)

# %%
rho = .5
mean_degree = 2
inferr = []
l2err = []
for i in range(25):
    inf, l2 = digraph_err(mean_degree, rho)
    inferr.append(inf)
    l2err.append(l2)
print(f"Error: {np.mean(inferr)} (Linf) {np.mean(l2err)} (L2)")
# Out:
# Error: 1618.5755735799287 (Linf) 1166.872785940835 (L2)

# %%
rho = 25
mean_degree = 2
inferr = []
l2err = []
for i in range(25):
    inf, l2 = digraph_err(mean_degree, rho)
    inferr.append(inf)
    l2err.append(l2)
print(f"Error: {np.mean(inferr)} (Linf) {np.mean(l2err)} (L2)")
# Out:
# Error: 2043.9529057900947 (Linf) 1812.1549738018339 (L2)

# %%
rho = 50
mean_degree = 2
inferr = []
l2err = []
for i in range(25):
    inf, l2 = digraph_err(mean_degree, rho)
    inferr.append(inf)
    l2err.append(l2)
print(f"Error: {np.mean(inferr)} (Linf) {np.mean(l2err)} (L2)")
# Out:
# Error: 3281.2849204854974 (Linf) 2609.8822966792836 (L2)

# %%
rho = .5
mean_degree = 0.1
inferr = []
l2err = []
for i in range(25):
    inf, l2 = digraph_err(mean_degree, rho)
    inferr.append(inf)
    l2err.append(l2)
print(f"Error: {np.mean(inferr)} (Linf) {np.mean(l2err)} (L2)")
# Out:
# Error: 2365.0643279852006 (Linf) 1194.7077299887721 (L2)

# %%
rho = 25
mean_degree = 0.1
inferr = []
l2err = []
for i in range(25):
    inf, l2 = digraph_err(mean_degree, rho)
    inferr.append(inf)
    l2err.append(l2)
print(f"Error: {np.mean(inferr)} (Linf) {np.mean(l2err)} (L2)")
# Out:
# Error: 1545.3212011549404 (Linf) 927.8518549160138 (L2)

# %%
rho = 50
mean_degree = 0.1
inferr = []
l2err = []
for i in range(25):
    inf, l2 = digraph_err(mean_degree, rho)
    inferr.append(inf)
    l2err.append(l2)
print(f"Error: {np.mean(inferr)} (Linf) {np.mean(l2err)} (L2)")
# Out:
# Error: 4095.2499914492755 (Linf) 1962.5424896076292 (L2)
