# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.integrate import odeint
from scipy.optimize import fsolve

# %%
plt.rcParams["figure.figsize"] = [10, 5]
x = np.linspace(-5, 5, 200)
activ_f = np.tanh
f = lambda x, rho, a: activ_f(rho * x + a)
r = 4
a = 7
purple = np.array([0.48396212, 0.24616213, 0.6241649 ])
niceblue=np.array([0,76,138])/255.0

plt.plot(x, x, c='k', lw=.5, label="$y = x$")
plt.plot(x, f(x, r, 0), c=purple, lw=3.0, label="$y = \\tanh (\\rho x + a)$")
plt.plot(x, f(x, r, -a), '--', c=purple,lw=3.0, alpha=0.7)
plt.plot(x, f(x, r, a), '--', c=purple,lw=3.0, alpha=0.7)
plt.plot(1, 1, 'o', c=niceblue)
plt.plot(-1, -1, 'o', c=niceblue)
plt.plot(0, 0, 'o', c="r")


plt.ylim([-2.5, 2.5])
plt.xlim([-3, 3])
plt.xticks([0])
plt.yticks([-1, 1], fontsize=18)
plt.xticks([-7/4, -1, 0, 1, 7/4], ["$-a/\\rho$","-1", "0", "1", "$a/\\rho$"], fontsize=18)
plt.legend(fontsize=18)
plt.title("Solutions of $r = \\tanh(\\rho r + a)$\n", fontsize=18)
plt.show()

# %% [markdown]
# # Jacobian Eigenvalue

# %%
plt.rcParams["figure.figsize"] = [10, 5]

def jac(r, rho=1, a=0):
    return rho / np.cosh(rho*r + a)**2 - 1
x = np.linspace(-5, 5, 1000)
niceblue=np.array([0,76,138])/255.0
#Positive and negative
for aval in [0, -a, a]:
    jac0 = jac(x, r, aval)
    ymask = jac0 > 0
    xmask = x < -aval/r
    
    linetype = "--"
    alpha = .7
    if aval == 0:
        linetype = ""
        alpha = 1.0
    plt.plot(x[ymask], jac0[ymask], linetype, c="r", lw=3.0, alpha=alpha)
    plt.plot(x[~ymask * xmask], jac0[~ymask * xmask], linetype, c=niceblue, lw=3.0, alpha=alpha)
    plt.plot(x[~ymask * ~xmask], jac0[~ymask * ~xmask], linetype, c=niceblue, lw=3.0, alpha=alpha)
#plt.plot(0, r - 1, c="r", label="$\\rho \\sech^2 (\\rho x + a) - 1$")

plt.plot(x, np.zeros(len(x)), c='gray', lw=0.5)

plt.ylim([-1.5, 3.5])
plt.xlim([-3, 3])
plt.xticks([0])
plt.yticks([-1, 1], fontsize=18)
plt.xticks([-7/4, -1, 0, 1, 7/4], ["$-a/\\rho$","-1", "0", "1", "$a/\\rho$"], fontsize=18)
#plt.legend(fontsize=18)
plt.title("Sign of $\\lambda = \\rho \\sech^2 (\\rho x + a) - 1$", fontsize=18)
plt.show()

# %%
def f(y,t):
    specw = np.array([.1, 1, 2, 5])
    sinw = 1.0*np.array([1, 1.,1, 1])
    return -y + np.tanh(specw*y + sinw * np.sin(t))

# %%
plt.rcParams["figure.figsize"] = [10, 7]

def f(y,t):
    specw = np.array([.25, 1, 2, 5])
    sinw = 1.0*np.array([1, 1.,1, 1])
    return -y + np.tanh(specw*y + sinw * np.sin(t))
end = 12*np.pi
t =  np.linspace(0, end, 500)
orbit = odeint(f, [0, 0,0, 0], t)

color = np.array([0.2397127 , 0.77365814, 0.54752115])
spect = [.25, 1, 2, 5]

for i in range(3, -1, -1):
    col = color + i*np.array([.05, -.25, .05])
    plt.plot(t, orbit[:,i], lw=3, c=col)
    plt.plot(t[0], orbit[0, i], c=col, label=f"Sepcetral Radius = {spect[i]}")
#plt.legend()
plt.title("Effect of Spectral Radius on Node Responsiveness \n", fontsize=20)
plt.ylim([-1.1, 1.1])
plt.xlim([0, end + 1])
plt.xticks([0])
plt.yticks([], fontsize=18)
plt.xticks([0, 15, 30], fontsize=18)
plt.xlabel("Time", fontsize=16)
#plt.ylabel("Node State", fontsize=16)

plt.show()

# Error Computation
U = np.sin(t)
Y = U @ orbit
W = Y @ np.linalg.inv(orbit.T @ orbit)
pre = orbit @ W

print(f"L2 Error: {np.mean(np.abs(pre - U))}")
print(f"Linf Error: {np.max(np.abs(pre - U))}")
# Out:
# L2 Error: 0.095788312812583
# Linf Error: 0.4813041692985329

# %% [markdown]
# ## Increase input

# %%
def f(y,t):
    specw = np.array([.25, 1, 2, 5])
    sinw = 3*np.array([1, 1.,1, 1])
    return -y + np.tanh(specw*y + sinw * np.sin(t))

orbit = odeint(f, [0, 0,0, 0], np.linspace(0, 12*np.pi, 500))

color = np.array([0.2397127 , 0.77365814, 0.54752115])
spect = [.25, 1, 2, 5]

for i in range(3, -1, -1):
    col = color + i*np.array([.05, -.25, .05])
    plt.plot(t, orbit[:,i], lw=3, c=col)
    plt.plot(t[0], orbit[0, i], c=col, label=f"Sepcetral Radius = {spect[i]}")
#plt.legend()
plt.title("Increase input magnitude ($b = 3$)", fontsize=18)
plt.ylim([-1.1, 1.1])
plt.xlim([0, end + 1])
plt.xticks([0])
plt.yticks([], fontsize=18)
plt.xticks([0, 15, 30], fontsize=18)
plt.xlabel("Time", fontsize=16)
#plt.ylabel("Node State", fontsize=16)
plt.show()

U = np.sin(t)
Y = U @ orbit
W = Y @ np.linalg.inv(orbit.T @ orbit)
pre = orbit @ W

print(f"Error: {np.mean(np.abs(pre - U))}")
print(f"Linf Error: {np.max(np.abs(pre - U))}")
# Out:
# Error: 0.18666235973614692
# Linf Error: 0.5076170250723074

# %% [markdown]
# ## Decrease Input

# %%
def f(y,t):
    specw = np.array([.25, 1, 2, 5])
    sinw = .25*np.array([1, 1.,1, 1])
    return -y + np.tanh(specw*y + sinw * np.sin(t))

orbit = odeint(f, [0, 0,0, 0], np.linspace(0, 12*np.pi, 500))

color = np.array([0.2397127 , 0.77365814, 0.54752115])
spect = [.25, 1, 2, 5]

for i in range(3, -1, -1):
    col = color + i*np.array([.05, -.25, .05])
    plt.plot(t, orbit[:,i], lw=3, c=col)
    plt.plot(t[0], orbit[0, i], c=col, label=f"Spectral Radius: {spect[i]}")
plt.legend(loc=(0.3,0.05), fontsize=18)
plt.title("Decrease input magnitude ($b=0.25$)", fontsize=18)
plt.ylim([-1.1, 1.1])
plt.xlim([0, end + 1])
plt.xticks([0])
plt.yticks([-1, 1], fontsize=18)
plt.xticks([0, 15, 30], fontsize=18)
plt.xlabel("Time", fontsize=16)
plt.ylabel("Node State", fontsize=16)
plt.show()

U = np.sin(t)
Y = U @ orbit
W = Y @ np.linalg.inv(orbit.T @ orbit)
pre = orbit @ W

print(f"Error: {np.mean(np.abs(pre - U))}")
print(f"Linf Error: {np.max(np.abs(pre - U))}")
# Out:
# Error: 0.16991433455577418
# Linf Error: 0.4746452285713465

# %%
from scipy.optimize import fsolve

# %% [markdown]
# ## Blind Oscillation

# %%
plt.rcParams["figure.figsize"] = [10,4]

# %%
def sinc(t,a=0):
    # Use series expansion if t is too small
    if np.abs(t-a) < 0.1:
        return 1 - (t-a)**2/6 + (t-a)**4/120
    return np.sin(t - a)/(t - a)

t = np.linspace(0, 12*np.pi, 1000)

plt.plot(t, [sinc(ti, a=np.pi*6) for ti in t], c=niceblue, lw=2)
plt.title("Input signal: $A\\sinc(t)$", fontsize=16)
plt.xticks([], fontsize=14)
plt.yticks([0, 1], fontsize=14)
#plt.xlabel("Time")
plt.show()

# %%
def g(y, t):
    rho = .25
    b = 50
    return -y + np.tanh(rho*y + b*sinc(t, a=6*np.pi))

t = np.linspace(0, 12*np.pi, 1000)
x0 = .5
fp = [fsolve(lambda x: g(x, t0), x0) for t0 in t]
plt.plot(t, fp, c="k", lw=2, label="Fixed Point")

orbit = odeint(g, [0, 0,0, 0], np.linspace(0, 12*np.pi, 1000))
col = np.random.rand(3)
plt.plot(t, orbit, lw=2, c=col)
plt.plot(0, orbit[0,0], c=col, label="Reservoir Node")
plt.title("Evolution of Fixed Point vs. Evolution of Reservoir Node (A = 50)")
plt.legend(loc="upper right")
plt.yticks([-1,1], fontsize=14)
plt.xticks([])
plt.show()

# %%
def g(y, t):
    rho = .25
    b = 5
    return -y + np.tanh(rho*y + b*sinc(t, a=6*np.pi))

t = np.linspace(0, 12*np.pi, 1000)
x0 = .5
fp = [fsolve(lambda x: g(x, t0), x0) for t0 in t]
plt.plot(t,fp, c="k", lw=2, label="Fixed Point")

orbit = odeint(g, [0, 0,0, 0], np.linspace(0, 12*np.pi, 1000))
col = np.random.rand(3)
plt.plot(t, orbit, lw=2, c=col)
plt.plot(0, orbit[0,0], c=col, label="Reservoir Node")
plt.title("Evolution of Fixed Point vs. Evolution of Reservoir Node (A = 5)")
plt.yticks([-1,1], fontsize=14)
plt.xticks([10,20,30], fontsize=14)
plt.xlabel("Time", fontsize=14)
plt.legend()
plt.show()
