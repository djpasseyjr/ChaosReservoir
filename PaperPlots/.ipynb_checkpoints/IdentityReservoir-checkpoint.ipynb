# %% [markdown]
# # Plotting response of the Identity Reservoir as Spectral Radius Changes
#
# **NOTE THIS USES THE NEW `rescomp` PACKAGE DOWNLOADABLE WITH PIP**

# %%
import rescomp as rc
import numpy as np
from matplotlib import pyplot as plt

# %%
RES_PARAMS = {
              "uniform_weights": True,
              "ridge_alpha": 1e-6,
              "signal_dim": 3,
              "res_sz": 50,
              "activ_f": np.tanh,
              "spect_rad": 5,
              "gamma": 5,
              "sigma": .14,
             }

def decoupled_err(rho):
    I = np.eye(n) * rho
    rcomp = rc.ResComp(I, **RES_PARAMS)
    t, U = rc.orbit("lorenz", trim=True)
    r0 = np.random.rand(n)*2 - 1
    R = rcomp.internal_state_response(t, U, r0)
    plt.plot(t - 40, R)
    plt.show()

    Wout = U.T @ R @ np.linalg.inv(R.T @ R)
    Uhat = (Wout@R.T).T
    inferr = np.max(np.abs(Uhat - U))
    l2err = np.mean(np.sum((Uhat - U)**2, axis=1)**.5)
    return inferr, l2err

# %% [markdown]
# ## Decoupled Reservoir Node States. Spectral Radius = 0.25

# %%
n = RES_PARAMS["res_sz"]
rho = .25
I = np.eye(n) * rho
rcomp = rc.ResComp(I, **RES_PARAMS)
t, U = rc.orbit("lorenz", trim=True)
r0 = np.random.rand(n)*2 - 1

# %%
R = rcomp.internal_state_response(t, U, r0)
plt.plot(t - 40, R)
plt.show()

Wout = U.T @ R @ np.linalg.inv(R.T @ R)
Uhat = (Wout@R.T).T
#plt.plot(Uhat)
err = np.max(np.abs(Uhat - U))
print(f"Error {err} (Probably should do mean)")
# Out:
# Error 1.0088298496463697 (Probably should do mean)

# %% [markdown]
# ## Spectral Radius = 0.25 Mean Error

# %% [markdown]
# ## Decoupled Reservoir Node States. Spectral Radius = 1.5

# %%
n = RES_PARAMS["res_sz"]
rho = 1.5
I = np.eye(n) * rho
rcomp = rc.ResComp(I, **RES_PARAMS)
t, U = rc.orbit("lorenz", trim=True)
r0 = np.random.rand(n)*2 - 1

# %%
R = rcomp.internal_state_response(t, U, r0)
plt.plot(t - 40, R)
plt.show()

Wout = U.T @ R @ np.linalg.inv(R.T @ R)
Uhat = (Wout@R.T).T
#plt.plot(Uhat)
err = np.max(np.abs(Uhat - U))
print(f"Error {err}")
# Out:
# Error 0.43831912371345183

# %% [markdown]
# ## Decoupled Reservoir Node States. Spectral Radius = 3.0

# %%
n = RES_PARAMS["res_sz"]
rho = 3.0
I = np.eye(n) * rho
rcomp = rc.ResComp(I, **RES_PARAMS)
t, U = rc.orbit("lorenz", trim=True)
r0 = np.random.rand(n)*2 - 1

# %%
R = rcomp.internal_state_response(t, U, r0)
plt.plot(t - 40, R)
plt.show()


Wout = U.T @ R @ np.linalg.inv(R.T @ R)
Uhat = (Wout@R.T).T
#plt.plot(Uhat)
err = np.max(np.abs(Uhat - U))
print(f"Error {err}")
# Out:
# Error 1.5421359298524226
